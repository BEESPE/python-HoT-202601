# %% [markdown]
# ### Identify outliers in `products.csv`
#
# Use `pandas` to load and analyze the data from the CSV file `products.csv`. Detect outliers (order of magnitude: a few hundred).

# %%
# Your code here

# %% [markdown]
# Bonus: revisit the study of a typology of outliers using Dask.

# %%
# Your code here
